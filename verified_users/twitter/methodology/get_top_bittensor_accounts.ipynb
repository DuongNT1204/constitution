# %%
import pandas as pd
import numpy as np

filename = "/content/top_posts_50_likes_3_replies_5_rt.csv"
author_data_dict = {}

try:
    # 1. Load and process the data from the CSV file (same as before)
    print(f"🔄 Loading data from {filename}...")
    df = pd.read_csv(filename)

    required_cols = ['author.userName', 'author.id', 'viewCount', 'quoteCount', 'retweetCount', 'replyCount', 'likeCount']
    if not all(col in df.columns for col in required_cols):
        missing = [col for col in required_cols if col not in df.columns]
        raise ValueError(f"Missing required columns: {', '.join(missing)}")

    engagement_cols = ['viewCount', 'quoteCount', 'retweetCount', 'replyCount', 'likeCount']
    df[engagement_cols] = df[engagement_cols].fillna(0).astype(int)

    print("⚙️  Processing initial data...")
    for index, row in df.iterrows():
        author_username = row['author.userName']
        if pd.notna(author_username):
            engagement_score = (row['viewCount'] + row['quoteCount'] * 1000 + row['retweetCount'] * 500 + row['replyCount'] * 200 + row['likeCount'] * 100)
            if author_username not in author_data_dict:
                author_data_dict[author_username] = {'id': row['author.id'], 'tweets': 1, 'engagement': engagement_score}
            else:
                author_data_dict[author_username]['tweets'] += 1
                author_data_dict[author_username]['engagement'] += engagement_score

    # 2. Calculate totals needed for your formula
    num_authors = len(author_data_dict)
    total_tweets = sum(data['tweets'] for data in author_data_dict.values())
    total_engagement = sum(data['engagement'] for data in author_data_dict.values())

    print("📊 Calculating final scores based on your formula...")
    final_results = []

    # Check for division by zero
    if total_tweets == 0 or total_engagement == 0:
        raise ValueError("Total tweets or total engagement is zero, cannot calculate scores.")

    # 3. Loop through each author to calculate their final score
    for author_name, data in author_data_dict.items():
        their_num_tweet = data['tweets']
        their_engagement = data['engagement']

        # Your formula: 0.5 * num_authors * their_num_tweet / total_tweets + 0.5 * num_authors * their_engagement / total_engagement
        tweet_component = 0.5 * num_authors * their_num_tweet / total_tweets
        engagement_component = 0.5 * num_authors * their_engagement / total_engagement
        final_score = tweet_component + engagement_component

        final_results.append({
            'author': author_name,
            'tweets': their_num_tweet,
            'engagement': their_engagement,
            'final_score': final_score
        })

    # 4. Sort results by the final score
    sorted_results = sorted(final_results, key=lambda x: x['final_score'], reverse=True)

    # 5. Print the final ranked list
    print("\n--- 🏆 Authors Ranked by Final Score (Average = 1.0) ---")
    for result in sorted_results:
        print(f"{result['author']} - Final Score: {result['final_score']:.2f} "
              f"({result['tweets']} tweets, {result['engagement']:,} engagement)")

except FileNotFoundError:
    print(f"❌ Error: The file '{filename}' was not found.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

# --- 6. Prepare and Save Final Results to CSV ---
output_filename = "author_scores.csv"

# Add the author ID to the results and rename 'final_score' to 'weight'
final_data_for_csv = []
for result in sorted_results:
    author = result['author']
    final_data_for_csv.append({
        'author': author,
        'id': author_data_dict[author]['id'],
        'num_tweets': result['tweets'],
        'engagement': result['engagement'],
        'weight': result['final_score']
    })

print(f"\n💾 Saving results to {output_filename}...")

# Create a DataFrame with the correct columns and order
output_df = pd.DataFrame(final_data_for_csv)
output_df = output_df[['author', 'id', 'num_tweets', 'engagement', 'weight']]

# Save the DataFrame to a CSV file, without the index column
output_df.to_csv(output_filename, index=False)

print(f"✅ Successfully saved the ranked results to {output_filename}")
# Out:
# 🔄 Loading data from /content/top_posts_50_likes_3_replies_5_rt.csv...
# ⚙️  Processing initial data...
# 📊 Calculating final scores based on your formula...
#
# --- 🏆 Authors Ranked by Final Score (Average = 1.0) ---
# DreadBong0 - Final Score: 9.53 (17 tweets, 1,724,229 engagement)
# JosephJacks_ - Final Score: 7.31 (19 tweets, 898,793 engagement)
# BarrySilbert - Final Score: 5.39 (7 tweets, 1,162,231 engagement)
# markjeffrey - Final Score: 4.47 (12 tweets, 523,187 engagement)
# AltcoinDaily - Final Score: 3.44 (2 tweets, 915,599 engagement)
# Carloxir - Final Score: 3.31 (8 tweets, 450,446 engagement)
# opentensor - Final Score: 3.14 (7 tweets, 470,124 engagement)
# DrocksAlex2 - Final Score: 2.64 (7 tweets, 314,648 engagement)
# Defi0xJeff - Final Score: 2.55 (5 tweets, 430,124 engagement)
# 0xPrismatic - Final Score: 2.33 (5 tweets, 360,675 engagement)
# SiamKidd - Final Score: 2.19 (6 tweets, 247,735 engagement)
# coingecko - Final Score: 2.05 (2 tweets, 488,068 engagement)
# Grayscale - Final Score: 2.03 (4 tweets, 339,738 engagement)
# macrocrux - Final Score: 1.98 (1 tweets, 537,206 engagement)
# const_reborn - Final Score: 1.92 (5 tweets, 234,571 engagement)
# KeithSingery - Final Score: 1.71 (5 tweets, 171,718 engagement)
# here4impact - Final Score: 1.65 (4 tweets, 222,107 engagement)
# NATIXNetwork - Final Score: 1.51 (3 tweets, 251,651 engagement)
# _taofi_ - Final Score: 1.44 (3 tweets, 228,742 engagement)
# bittingthembits - Final Score: 1.42 (2 tweets, 294,589 engagement)
# qBitTensor - Final Score: 1.28 (3 tweets, 180,542 engagement)
# proofoftalk - Final Score: 1.28 (3 tweets, 179,723 engagement)
# rob_svrn - Final Score: 1.03 (1 tweets, 245,575 engagement)
# dotkrueger - Final Score: 0.99 (2 tweets, 162,875 engagement)
# coinbureau - Final Score: 0.97 (1 tweets, 228,193 engagement)
# CreatorBid - Final Score: 0.97 (2 tweets, 156,069 engagement)
# taoinsider - Final Score: 0.96 (2 tweets, 154,705 engagement)
# EvanMalanga - Final Score: 0.96 (3 tweets, 83,218 engagement)
# GidiGambino - Final Score: 0.92 (1 tweets, 213,271 engagement)
# webuildscore - Final Score: 0.92 (3 tweets, 70,899 engagement)
# S4mmyEth - Final Score: 0.91 (1 tweets, 209,795 engagement)
# simplytao_ - Final Score: 0.90 (1 tweets, 204,958 engagement)
# MessariCrypto - Final Score: 0.84 (1 tweets, 188,505 engagement)
# RvCrypto - Final Score: 0.83 (2 tweets, 114,706 engagement)
# jkrdoc - Final Score: 0.82 (2 tweets, 109,234 engagement)
# getmasafi - Final Score: 0.80 (2 tweets, 104,991 engagement)
# YumaGroup - Final Score: 0.79 (2 tweets, 101,824 engagement)
# BitGo - Final Score: 0.75 (1 tweets, 160,236 engagement)
# mxmsbt - Final Score: 0.74 (2 tweets, 84,602 engagement)
# ch_egan - Final Score: 0.73 (2 tweets, 83,743 engagement)
# MacrocosmosAI - Final Score: 0.71 (2 tweets, 74,986 engagement)
# jaltucher - Final Score: 0.68 (2 tweets, 66,148 engagement)
# GeckoTerminal - Final Score: 0.66 (1 tweets, 130,906 engagement)
# Degen_Hardy - Final Score: 0.64 (1 tweets, 127,231 engagement)
# gmoneyNFT - Final Score: 0.64 (2 tweets, 53,998 engagement)
# Victor_crypto_ - Final Score: 0.61 (2 tweets, 44,699 engagement)
# 0xarrash - Final Score: 0.59 (2 tweets, 38,466 engagement)
# Phonger24 - Final Score: 0.58 (2 tweets, 37,430 engagement)
# CrucibleLabs - Final Score: 0.58 (1 tweets, 107,341 engagement)
# nordin_eth - Final Score: 0.57 (1 tweets, 105,035 engagement)
# CopperHQ - Final Score: 0.56 (1 tweets, 100,933 engagement)
# Defimark7 - Final Score: 0.55 (1 tweets, 99,623 engagement)
# raintures - Final Score: 0.55 (1 tweets, 97,914 engagement)
# fundstrat - Final Score: 0.52 (1 tweets, 88,816 engagement)
# Kellykellam - Final Score: 0.51 (1 tweets, 85,752 engagement)
# CoinLiquidity - Final Score: 0.50 (1 tweets, 83,767 engagement)
# DeepFakeAI_ - Final Score: 0.49 (1 tweets, 80,609 engagement)
# Route2FI - Final Score: 0.49 (1 tweets, 78,517 engagement)
# Crypt0_DeFi - Final Score: 0.49 (1 tweets, 78,325 engagement)
# degenrsc - Final Score: 0.48 (1 tweets, 76,793 engagement)
# JohnnyZcash - Final Score: 0.47 (1 tweets, 74,329 engagement)
# CipherResearchx - Final Score: 0.47 (1 tweets, 72,660 engagement)
# cryptosanthoshK - Final Score: 0.46 (1 tweets, 71,543 engagement)
# kriptomete_ - Final Score: 0.46 (1 tweets, 70,946 engagement)
# PrudentSammy - Final Score: 0.44 (1 tweets, 65,669 engagement)
# borsaressami - Final Score: 0.44 (1 tweets, 63,291 engagement)
# bittensorai - Final Score: 0.41 (1 tweets, 56,578 engagement)
# coinagend - Final Score: 0.41 (1 tweets, 55,027 engagement)
# cryptorinweb3 - Final Score: 0.40 (1 tweets, 53,221 engagement)
# TedPillows - Final Score: 0.40 (1 tweets, 51,836 engagement)
# wolftensor - Final Score: 0.39 (1 tweets, 50,097 engagement)
# mikocryptonft - Final Score: 0.39 (1 tweets, 48,531 engagement)
# hyperlane - Final Score: 0.39 (1 tweets, 47,761 engagement)
# polkaguy - Final Score: 0.39 (1 tweets, 47,448 engagement)
# SturdyFinance - Final Score: 0.38 (1 tweets, 45,715 engagement)
# philism_ - Final Score: 0.37 (1 tweets, 43,004 engagement)
# CryptoFuegoYT - Final Score: 0.37 (1 tweets, 42,487 engagement)
# synapz_org - Final Score: 0.37 (1 tweets, 42,290 engagement)
# TheEuroSniper - Final Score: 0.36 (1 tweets, 40,929 engagement)
# officialneeve - Final Score: 0.36 (1 tweets, 39,494 engagement)
# Ebubechi_GMI - Final Score: 0.35 (1 tweets, 38,008 engagement)
# SatoshiFlipper - Final Score: 0.35 (1 tweets, 37,412 engagement)
# Victor_crypto_2 - Final Score: 0.35 (1 tweets, 36,886 engagement)
# dippy_eth - Final Score: 0.34 (1 tweets, 34,524 engagement)
# m2globalmoney - Final Score: 0.34 (1 tweets, 33,977 engagement)
# FortKnoxCrypto - Final Score: 0.33 (1 tweets, 31,270 engagement)
# Old_Samster - Final Score: 0.33 (1 tweets, 31,053 engagement)
# TAOSynergies - Final Score: 0.33 (1 tweets, 29,733 engagement)
# the_mattyk - Final Score: 0.33 (1 tweets, 29,624 engagement)
# BTCmask_AI - Final Score: 0.32 (1 tweets, 28,945 engagement)
# mogmachine - Final Score: 0.32 (1 tweets, 28,506 engagement)
# DavFields - Final Score: 0.32 (1 tweets, 28,375 engagement)
# chiefingza - Final Score: 0.32 (1 tweets, 27,623 engagement)
# TaoPortal - Final Score: 0.32 (1 tweets, 26,802 engagement)
# TalkingTensor - Final Score: 0.31 (1 tweets, 24,948 engagement)
# cryptoboys27 - Final Score: 0.31 (1 tweets, 24,309 engagement)
# DistStateAndMe - Final Score: 0.31 (1 tweets, 23,968 engagement)
# boz_menzalji - Final Score: 0.31 (1 tweets, 23,350 engagement)
# markcreaser - Final Score: 0.31 (1 tweets, 23,280 engagement)
# pgpsam - Final Score: 0.30 (1 tweets, 20,884 engagement)
# yanez__ai - Final Score: 0.30 (1 tweets, 20,540 engagement)
# TAOTemplar - Final Score: 0.29 (1 tweets, 19,714 engagement)
# Lazz_eth - Final Score: 0.29 (1 tweets, 17,685 engagement)
# Vayu108 - Final Score: 0.29 (1 tweets, 17,041 engagement)
# bittensor_ - Final Score: 0.28 (1 tweets, 15,019 engagement)
# NFTLunatic - Final Score: 0.28 (1 tweets, 14,966 engagement)
# dippy_ai - Final Score: 0.28 (1 tweets, 14,061 engagement)
# dTAOfordummies - Final Score: 0.27 (1 tweets, 13,276 engagement)
# YVR_Trader - Final Score: 0.27 (1 tweets, 11,720 engagement)
#
# 💾 Saving results to author_scores.csv...
# ✅ Successfully saved the ranked results to author_scores.csv
